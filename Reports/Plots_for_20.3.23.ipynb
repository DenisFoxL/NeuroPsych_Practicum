# %%
import sys
import os
sys.path.append(os.path.abspath('../Functions'))

# %%
import Functions.Organizing_funcs as of
import Functions.Perliminary_plots as pp
import Functions.Statistic_funcs as sf
# Out:
# C:\Users\denis\anaconda3\envs\Geeshot\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
path=r'C:\Users\denis\Downloads\Homework\Neuropsychology\HBN\Data\data-2023-03-20.csv'
data=of.clean(path)
data=of.calculate_score(data,'CBCL','CBCl_OC_Raw')
main_cols=['Basic_Demos,Age', 'Basic_Demos,Sex','CBCL,CBCL_AD', 'SDS,SDS_Total_Raw','CBCl_OC_Raw']
# Out:
# C:\Users\denis\Downloads\Homework\Neuropsychology\HBN\Functions\Organizing_funcs.py:26: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   data.iloc[:, 3:] = data.iloc[:, 3:].astype('float64')

# %% [markdown]
# ## Scatterplots to visualize data

# %%
pp.scatter(data,['Basic_Demos,Age','CBCl_OC_Raw'])
pp.scatter(data,['Basic_Demos,Age','SDS,SDS_Total_Raw'])
pp.scatter(data,['SDS,SDS_Total_Raw','CBCl_OC_Raw'])

# %% [markdown]
# ## Correlation matrix

# %% [markdown]
# #### (age\sex\CBCL depression\SDS sleep\CBCL OCs

# %%
corr_data=data.loc[:,main_cols]
pp.correlation_mat_plot(corr_data)

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# Predicting OCs from sleep, with depression as covariate

# %%
model=sf.linear_reg(data,'SDS,SDS_Total_Raw','CBCl_OC_Raw',[])
coef=model.coef_
print(f'The coefficient for SDS sleep score is: {coef[0]} and for CBCL depression score is: {coef[1]}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9652\3903557080.py in <module>
# ----> 1 model=sf.linear_reg(data,'SDS,SDS_Total_Raw','CBCl_OC_Raw',[])
#       2 coef=model.coef_
#       3 print(f'The coefficient for SDS sleep score is: {coef[0]} and for CBCL depression score is: {coef[1]}')
#
# NameError: name 'data' is not defined

# %%
print(os.path.join(os.path.abspath('../'),r'Data\cleaned.csv'))
# Out:
# C:\Users\denis\Downloads\Homework\Neuropsychology\HBN\Data\cleaned.csv

# %%
data.to_csv(os.path.join(os.path.abspath('../'),r'Data\cleaned_2023-03-20.csv'), index=False)
