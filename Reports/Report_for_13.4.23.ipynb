# %%
import sys
import os
sys.path.append(os.path.abspath('../Functions'))

# %%
import Functions.Perliminary_plots as pp
import Functions.Statistic_funcs as sf
import pandas as pd

# %%
path=r'C:\Users\denis\Downloads\Homework\Neuropsychology\HBN\Data\cleaned_2023-03-20.csv'
data=pd.read_csv(path)
main_cols=['CBCl_OC_Raw','Basic_Demos,Age', 'Basic_Demos,Sex','CBCL,CBCL_AD','SDS,SDS_DA_Raw','SDS,SDS_DIMS_Raw','SDS,SDS_DOES_Raw','SDS,SDS_SBD_Raw','SDS,SDS_SHY_Raw','SDS,SDS_SWTD_Raw','SDS,SDS_Total_Raw']

# %%
corr_data=data.loc[:,main_cols]
pp.plot_corr_mat(*sf.corr_mat(corr_data))

# %%
data['CBCl_OC_Raw'].plot(kind='hist', title='OCs Distribution')
# Out:
# <AxesSubplot:title={'center':'OCs Distribution'}, ylabel='Frequency'>
